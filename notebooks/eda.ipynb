# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading the dataset

# %%
data=pd.read_csv('C:\\Users\\gtani\\OneDrive\\Desktop\\Boston_House\\notebooks\\data\\boston.csv')

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
data.shape
# Out:
# (506, 14)

# %% [markdown]
# # Columns description
# - CRIM : per capita crime rate by town
# - ZN : proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS : proportion of non-retail business acres per town
# - CHAS : Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# - NOX : nitric oxides concentration (parts per 10 million)
# - RM : average number of rooms per dwelling
# - AGE : proportion of owner-occupied units built prior to 1940
# - DIS : weighted distances to five Boston employment centres
# - RAD : index of accessibility to radial highways
# - TAX : full-value property-tax rate per $10,000
# - PTRATIO : pupil-teacher ratio by town
# - B : 1000(Bk - 0.63)^2 where Bk is the proportion
# - LSTAT : % lower status of the population
# - MEDV : Median value of owner-occupied homes in $1000's  (target column)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %% [markdown]
# # CRIM : per capita crime rate by town
# ** conclusions
# - mean is about 3.6 ,so there are 18 outliers (above 20)
# - it is right skewed

# %%
data['CRIM'].describe()
# Out:
# count    506.000000
# mean       3.613524
# std        8.601545
# min        0.006320
# 25%        0.082045
# 50%        0.256510
# 75%        3.677083
# max       88.976200
# Name: CRIM, dtype: float64

# %%
data['CRIM'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['CRIM'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
data['CRIM'].plot(kind='box')
# Out:
# <Axes: >

# %%
(data['CRIM'] > 20).sum()
# Out:
# 18

# %% [markdown]
# # ZN : proportion of residential land zoned for lots over 25,000 sq.ft.
# ** conclusions
# - mean is 11 but max is 100
# - data is right skewed
# - 73% of the data is 0
# - above 40 only 51 values are there

# %%
data['ZN'].describe()
# Out:
# count    506.000000
# mean      11.363636
# std       23.322453
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       12.500000
# max      100.000000
# Name: ZN, dtype: float64

# %%
data['ZN'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['ZN'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
data['ZN'].plot(kind='box')
# Out:
# <Axes: >

# %%
(data['ZN']>40).sum()
# Out:
# 51

# %%
(data['ZN']==0).sum()/506
# Out:
# 0.7351778656126482

# %% [markdown]
# # INDUS : proportion of non-retail business acres per town
# ** conclusions
# - atleast no outliers

# %%
data['INDUS'].describe()
# Out:
# count    506.000000
# mean      11.136779
# std        6.860353
# min        0.460000
# 25%        5.190000
# 50%        9.690000
# 75%       18.100000
# max       27.740000
# Name: INDUS, dtype: float64

# %%
data['INDUS'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['INDUS'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
data['INDUS'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # CHAS : Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# ** conclusions
# - about 93% data has value equal to 0
# - only 7% has value equal to 1

# %%
data['CHAS'].describe()
# Out:
# count    506.000000
# mean       0.069170
# std        0.253994
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: CHAS, dtype: float64

# %%
(data['CHAS']==0).sum()/506
# Out:
# 0.9308300395256917

# %%
data['CHAS'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['CHAS'].plot(kind='box')
# Out:
# <Axes: >

# %%
data['CHAS'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # NOX : nitric oxides concentration (parts per 10 million)
# ** conclusions
# - almost normal
# - no outliers

# %%
data['NOX'].describe()
# Out:
# count    506.000000
# mean       0.554695
# std        0.115878
# min        0.385000
# 25%        0.449000
# 50%        0.538000
# 75%        0.624000
# max        0.871000
# Name: NOX, dtype: float64

# %%
data['NOX'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['NOX'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
data['NOX'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # RM : average number of rooms per dwelling
# ** conclusions
# - left skewed
# - mostly between 5 and 7

# %%
data['RM'].describe()
# Out:
# count    506.000000
# mean       6.284634
# std        0.702617
# min        3.561000
# 25%        5.885500
# 50%        6.208500
# 75%        6.623500
# max        8.780000
# Name: RM, dtype: float64

# %%
data['RM'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['RM'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
data['RM'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # AGE : proportion of owner-occupied units built prior to 1940
# ** conclusions
# - left skewed

# %%
data['AGE'].describe()
# Out:
# count    506.000000
# mean      68.574901
# std       28.148861
# min        2.900000
# 25%       45.025000
# 50%       77.500000
# 75%       94.075000
# max      100.000000
# Name: AGE, dtype: float64

# %%
data['AGE'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['AGE'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
data['AGE'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# #  DIS : weighted distances to five Boston employment centres
# ** conclusions
# - right skewed

# %%
data['DIS'].describe()
# Out:
# count    506.000000
# mean       3.795043
# std        2.105710
# min        1.129600
# 25%        2.100175
# 50%        3.207450
# 75%        5.188425
# max       12.126500
# Name: DIS, dtype: float64

# %%
data['DIS'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
data['DIS'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # RAD : index of accessibility to radial highways
# ** conclusions
# - right skewed

# %%
data['RAD'].describe()
# Out:
# count    506.000000
# mean       9.549407
# std        8.707259
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%       24.000000
# max       24.000000
# Name: RAD, dtype: float64

# %%
data['RAD'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # TAX : full-value property-tax rate per $10,000
# ** conclusions

# %%
data['TAX'].describe()
# Out:
# count    506.000000
# mean     408.237154
# std      168.537116
# min      187.000000
# 25%      279.000000
# 50%      330.000000
# 75%      666.000000
# max      711.000000
# Name: TAX, dtype: float64

# %%
data['TAX'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# #  PTRATIO : pupil-teacher ratio by town
# ** conclusions
# - The PTRATIO is left skewed

# %%
data['PTRATIO'].describe()
# Out:
# count    506.000000
# mean      18.455534
# std        2.164946
# min       12.600000
# 25%       17.400000
# 50%       19.050000
# 75%       20.200000
# max       22.000000
# Name: PTRATIO, dtype: float64

# %%
data['PTRATIO'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
data['PTRATIO'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # B : 1000(Bk - 0.63)^2 where Bk is the proportion
# ** conclusions
# - left skewed
# - mainly data lies between 300 and 400

# %%
data['B'].describe()
# Out:
# count    506.000000
# mean     356.674032
# std       91.294864
# min        0.320000
# 25%      375.377500
# 50%      391.440000
# 75%      396.225000
# max      396.900000
# Name: B, dtype: float64

# %%
data['B'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # LSTAT : % lower status of the population
# ** conclusions
# -almost normal

# %%
data['LSTAT'].describe()
# Out:
# count    506.000000
# mean      12.653063
# std        7.141062
# min        1.730000
# 25%        6.950000
# 50%       11.360000
# 75%       16.955000
# max       37.970000
# Name: LSTAT, dtype: float64

# %%
data['LSTAT'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# CRIM vs MEDV
sns.scatterplot(x='CRIM',y='MEDV',data=data)
# Out:
# <Axes: xlabel='CRIM', ylabel='MEDV'>

# %%
# ZN vs MEDV
sns.scatterplot(x='ZN',y='MEDV',data=data)
# Out:
# <Axes: xlabel='ZN', ylabel='MEDV'>

# %%
# INDUS vs MEDV
sns.scatterplot(x='INDUS',y='MEDV',data=data)
# Out:
# <Axes: xlabel='INDUS', ylabel='MEDV'>

# %%
# CHAS vs MEDV
sns.scatterplot(x='CHAS',y='MEDV',data=data)
# Out:
# <Axes: xlabel='CHAS', ylabel='MEDV'>

# %%
# NOX vs MEDV
sns.scatterplot(x='NOX',y='MEDV',data=data)
# Out:
# <Axes: xlabel='NOX', ylabel='MEDV'>

# %%
#   RM vs MEDV
sns.scatterplot(x='RM',y='MEDV',data=data)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
# AGE vs MEDV
sns.scatterplot(x='AGE',y='MEDV',data=data)
# Out:
# <Axes: xlabel='AGE', ylabel='MEDV'>

# %%
# DIS vs MEDV
sns.scatterplot(x='DIS',y='MEDV',data=data)
# Out:
# <Axes: xlabel='DIS', ylabel='MEDV'>

# %%
# RAD vs MEDV
sns.scatterplot(x='RAD',y='MEDV',data=data)
# Out:
# <Axes: xlabel='RAD', ylabel='MEDV'>

# %%
# TAX vs MEDV
sns.scatterplot(x='TAX',y='MEDV',data=data)
# Out:
# <Axes: xlabel='TAX', ylabel='MEDV'>

# %%
# PTRATIO vs MEDV
sns.scatterplot(x='PTRATIO',y='MEDV',data=data)
# Out:
# <Axes: xlabel='PTRATIO', ylabel='MEDV'>

# %%
# B vs MEDV
sns.scatterplot(x='B',y='MEDV',data=data)
# Out:
# <Axes: xlabel='B', ylabel='MEDV'>

# %%
# LSTAT vs MEDV
sns.scatterplot(x='LSTAT',y='MEDV',data=data)
# Out:
# <Axes: xlabel='LSTAT', ylabel='MEDV'>

# %%
data.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
# we are considering all the features here
